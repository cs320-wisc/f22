# %% [markdown]
# # Binary Search Trees

# %%
# root: any node with no parents
# leaf: any node with no children
# tree: is a DAG (directed acyclic graph) with only one root; any other nodes have exactly one parent

from graphviz import Digraph
g = Digraph()
g.edge("1", "2", label="left")
g.edge("1", "3", label="right")
g

# linked list: a tree, where each node has at MOST one child
# binary tree:  a tree, where each has at MOST two children

# %%
class Node:
    def __init__(self, label):
        self.label = label
        self.left = None
        self.right = None
    
    # situation 2: a function that does something (e.g., printing)
    # prints out name of every node in the tree
    def dump(self, prefix="", suffix=""):
        print(prefix, self.label, suffix)
        if self.left != None:
            self.left.dump(prefix+"\t", "(LEFT)")
        if self.right != None:
            self.right.dump(prefix+"\t", "(RIGHT)")
            
    # situation 1: a function that returns something
    # return True/False, if target is somewhere in the tree
    def search(self, target):
        print("CHECK", self.label)
        if target == self.label:
            return True

        if self.left != None:
            if self.left.search(target):
                return True
        
        if self.right != None:
            if self.right.search(target):
                return True
        
        return False

node1 = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node1.left = node2
node1.right = node3
node2.left = node4
node1.dump()
node1.search(3) # should be True

# how many times is search(...) called, in the worst case?  Assume N nodes.  N times.
# complexity is O(N)
# Out:
#  1
# 	 2 (LEFT)
# 		 4 (LEFT)
# 	 3 (RIGHT)
# CHECK 1
# CHECK 2
# CHECK 4
# CHECK 3
# True

# %%
class Node:
    def __init__(self, label):
        self.label = label
        self.left = None
        self.right = None
    
    # situation 2: a function that does something (e.g., printing)
    # prints out name of every node in the tree
    def dump(self, prefix="", suffix=""):
        print(prefix, self.label, suffix)
        if self.left != None:
            self.left.dump(prefix+"\t", "(LEFT)")
        if self.right != None:
            self.right.dump(prefix+"\t", "(RIGHT)")
            
    # situation 1: a function that returns something
    # return True/False, if target is somewhere in the tree
    def search(self, target):
        if target == self.label:
            return True

        if target < self.label:
            if self.left != None:
                if self.left.search(target):
                    return True

        elif target > self.label:
            if self.right != None:
                if self.right.search(target):
                    return True
        
        return False

root = Node(10)
root.left = Node(2)
root.left.left = Node(1)
root.left.right = Node(4)
root.left.right.right = Node(8)
root.left.right.left = Node(3)
root.right = Node(15)
root.right.left = Node(12)
root.right.right = Node(19)
#root.right.left.left = Node(8)
root.dump()
root.search(123)
# Out:
#  10
# 	 2 (LEFT)
# 		 1 (LEFT)
# 		 4 (RIGHT)
# 			 3 (LEFT)
# 			 8 (RIGHT)
# 	 15 (RIGHT)
# 		 12 (LEFT)
# 		 19 (RIGHT)
# False

# %%
# BST (Binary Search Tree):
# 1. BST rule: any node's value is bigger than every value in its left subtree, and
#              and smaller than every value in its right subtree
# 2. write an efficient search for a BST
# 3. write a method to add values to a BST, while preserving the BST rule

# %%
# BST (binary search tree) search: find a value; restrict structure of tree for efficient search
# DFS (depth-first search): find a path from one node to another -- any directed graph is OK

# %%
# functions:
# 1. add() that follows the BST rule
# 2. height() -- the number of nodes on the longest root-to-leaf path

class Node:
    def __init__(self, label):
        self.label = label
        self.left = None
        self.right = None
    
    # situation 2: a function that does something (e.g., printing)
    # prints out name of every node in the tree
    def dump(self, prefix="", suffix=""):
        print(prefix, self.label, suffix)
        if self.left != None:
            self.left.dump(prefix+"\t", "(LEFT)")
        if self.right != None:
            self.right.dump(prefix+"\t", "(RIGHT)")
            
    # situation 1: a function that returns something
    # return True/False, if target is somewhere in the tree
    def search(self, target):
        if target == self.label:
            return True

        if target < self.label:
            if self.left != None:
                if self.left.search(target):
                    return True

        elif target > self.label:
            if self.right != None:
                if self.right.search(target):
                    return True
        
        return False
    
    def add(self, label):
        if label < self.label:
            # go left
            if self.left == None:
                self.left = Node(label)
            else:
                self.left.add(label)
        elif label > self.label:
            # go right
            if self.right == None:
                self.right = Node(label)
            else:
                self.right.add(label)
                
    def height(self):
        # left subtree has height 3, right subtree has height 5, total height=6
        # left subtree has height 3, right subtree has height 3, total height=4
        # left subtree has height 10, right subtree has height 0, total height=11
        # left subtree has height x, right subtree has height y, total height=max(x,y)+1
        if self.left == None:
            x = 0
        else:
            x = self.left.height()
        if self.right == None:
            y = 0
        else:
            y = self.right.height()
        return max(x,y)+1

values = [5,3,8,9,1,2]
root = Node(values[0])
for v in values[1:]:
    root.add(v)
root.dump()
root.height() # should be 4
# Out:
#  5
# 	 3 (LEFT)
# 		 1 (LEFT)
# 			 2 (RIGHT)
# 	 8 (RIGHT)
# 		 9 (RIGHT)
# 4

# %%
values = list(range(100))
values.sort()  # this leads to a very tall tree
root = Node(values[0])
for v in values[1:]:
    root.add(v)
root.height()
# Out:
# 100

# %%
import random

values = list(range(100))
random.shuffle(values)  # this leads to a shorter tree
root = Node(values[0])
for v in values[1:]:
    root.add(v)
root.height()
# Out:
# 12

# %%
root.dump()
# Out:
#  38
# 	 7 (LEFT)
# 		 4 (LEFT)
# 			 0 (LEFT)
# 				 1 (RIGHT)
# 					 2 (RIGHT)
# 						 3 (RIGHT)
# 			 6 (RIGHT)
# 				 5 (LEFT)
# 		 19 (RIGHT)
# 			 11 (LEFT)
# 				 10 (LEFT)
# 					 8 (LEFT)
# 						 9 (RIGHT)
# 				 15 (RIGHT)
# 					 12 (LEFT)
# 						 13 (RIGHT)
# 							 14 (RIGHT)
# 					 18 (RIGHT)
# 						 17 (LEFT)
# 							 16 (LEFT)
# 			 20 (RIGHT)
# 				 26 (RIGHT)
# 					 24 (LEFT)
# 						 22 (LEFT)
# 							 21 (LEFT)
# 							 23 (RIGHT)
# 						 25 (RIGHT)
# 					 36 (RIGHT)
# 						 35 (LEFT)
# 							 29 (LEFT)
# 								 27 (LEFT)
# 									 28 (RIGHT)
# 								 30 (RIGHT)
# 									 32 (RIGHT)
# 										 31 (LEFT)
# 										 33 (RIGHT)
# 											 34 (RIGHT)
# 						 37 (RIGHT)
# 	 84 (RIGHT)
# 		 67 (LEFT)
# 			 58 (LEFT)
# 				 46 (LEFT)
# 					 44 (LEFT)
# 						 43 (LEFT)
# 							 39 (LEFT)
# 								 42 (RIGHT)
# 									 41 (LEFT)
# 										 40 (LEFT)
# 						 45 (RIGHT)
# 					 51 (RIGHT)
# 						 50 (LEFT)
# 							 49 (LEFT)
# 								 48 (LEFT)
# 									 47 (LEFT)
# 						 55 (RIGHT)
# 							 52 (LEFT)
# 								 54 (RIGHT)
# 									 53 (LEFT)
# 							 57 (RIGHT)
# 								 56 (LEFT)
# 				 63 (RIGHT)
# 					 60 (LEFT)
# 						 59 (LEFT)
# 						 62 (RIGHT)
# 							 61 (LEFT)
# 					 66 (RIGHT)
# 						 64 (LEFT)
# 							 65 (RIGHT)
# 			 83 (RIGHT)
# 				 70 (LEFT)
# 					 69 (LEFT)
# 						 68 (LEFT)
# 					 80 (RIGHT)
# 						 73 (LEFT)
# 							 72 (LEFT)
# 								 71 (LEFT)
# 							 75 (RIGHT)
# 								 74 (LEFT)
# 								 77 (RIGHT)
# 									 76 (LEFT)
# 									 79 (RIGHT)
# 										 78 (LEFT)
# 						 81 (RIGHT)
# 							 82 (RIGHT)
# 		 90 (RIGHT)
# 			 89 (LEFT)
# 				 88 (LEFT)
# 					 85 (LEFT)
# 						 86 (RIGHT)
# 							 87 (RIGHT)
# 			 92 (RIGHT)
# 				 91 (LEFT)
# 				 96 (RIGHT)
# 					 94 (LEFT)
# 						 93 (LEFT)
# 						 95 (RIGHT)
# 					 99 (RIGHT)
# 						 97 (LEFT)
# 							 98 (RIGHT)
